# %%
import csv

# %%
IrregularCSV = [] # create an empty list for CSV list

# %%
IrregularCSV = csv.reader(open('C:\Users\howt51\Desktop\Untitled folder\sample.txt','rb'), delimiter = '\t')

# %%
print IrregularCSV

# %%
for row in IrregularCSV:
    print ', '.join(row)
# Out:
# m   (g   IlW  lffi, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# lfil  O  3 JUN  2015   lliJ, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# National Environment Agency   B Y: _ _ _ _ &2, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# Radiation Protection  and Nuclear  Science Department, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# Dose Report for Jan 2015-Mar 2015, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# _ _ 5 May 2015, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# SINGAPORE GENERAL HOSPITAL PTE LTD (4536), , , , , , , , , , , , , , , , , , , , , , , , , , ,
# DEPT OF DIAGNOSTIC RADIOLOGY, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# 1 HOSPITAL DRIVE, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# SINGAPORE GENERAL HOSPITAL SINGAPORE  169608, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# Attn: MS TOH HONG GUAN, , , , , , , , , , , , , , , , , , , , , , , , , , ,
# ...

# %%
for row in IrregularCSV:
    print ', '.join(row)
